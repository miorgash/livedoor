# %% [markdown]
# - 文章の長さ
# - 語の出現頻度

# %%
# primitive
import sys
import os
import pickle
import itertools
from joblib import Parallel, delayed
from pprint import pprint
import itertools
from collections import Counter
from time import time

# data handling
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# text
import MeCab
import spacy
import gensim
from gensim.models import KeyedVectors

# ml
# from sklearn.model_selection import 

# nn
import torch
from torch import nn
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import DataLoader
from torch.utils.data.dataset import random_split
from torchtext.vocab import Vocab

# **
# handmade libs
# *
src = '../../src'
if src not in sys.path: sys.path.append(src)

# constants
from const import *
constants = {k: v for k, v in locals().items() if k.isupper()}
pprint(constants)

# modules
from my_tokenizer import get_tokenizer
from livedoor_dataset import LivedoorDataset
# Out:
# /tmp/work/livedoor
# {'DEVICE': 'cuda',
#  'DIR_BIN': '/tmp/work/livedoor/bin',
#  'DIR_DATA': '/tmp/work/livedoor/data',
#  'DIR_LOG': '/tmp/work/livedoor/log',
#  'DIR_MECAB_DIC': '/usr/lib/x86_64-linux-gnu/mecab/dic/mecab-ipadic-neologd',
#  'DIR_MODEL': '/tmp/work/livedoor/model',
#  'ROOT': '/tmp/work/livedoor',
#  'SAMPLE_SENT': 'ワンマンライブに行きたい。',
#  'TOKENIZER': 'mecab'}

# %% [markdown]
# Functions

# %%
ld_df = pd.read_csv(os.path.join(DIR_DATA, 'livedoor&text=text.csv'))

# 概観
print(ld_df.shape)
display(ld_df.head())
display(pd.DataFrame(ld_df.media.value_counts()).sort_index().T.style.background_gradient('Blues', axis=1))
# Out:
# (7366, 2)
#    media                                               text
# 0      3  前回の「プロに聞く“合コンの極意”（前編）　合コンアナリスト水谷麻衣に聞く、合コンの勝ちパタ...
# 1      3  「3年で転職は早すぎる？」「将来が見えない」「仕事が面白くない」・・・若手社会人の悩みは尽き...
# 2      3  こんにちは、「ビズリーチ年収1000万円研究所」所長の佐藤和男です。この研究所では、年収10...
# 3      3  6月7日、表参道のカフェバー「MERCER CAFE TERRACE HOUSE」でHenn...
# 4      3  「3年で転職は早すぎる？」「将来が見えない」「仕事が面白くない」・・・若手社会人の悩みは尽き...
# <style  type="text/css" >
# #T_0f6e0_row0_col0,#T_0f6e0_row0_col1,#T_0f6e0_row0_col4,#T_0f6e0_row0_col8{
#             background-color:  #084488;
#             color:  #f1f1f1;
#         }#T_0f6e0_row0_col2{
#             background-color:  #084990;
#             color:  #f1f1f1;
#         }#T_0f6e0_row0_col3{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_0f6e0_row0_col5{
#             background-color:  #0d57a1;
#             color:  #f1f1f1;
#         }#T_0f6e0_row0_col6{
#             background-color:  #3787c0;
#             color:  #000000;
#         }#T_0f6e0_row0_col7{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }</style><table id="T_0f6e0_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >2</th>        <th class="col_heading level0 col3" >3</th>        <th class="col_heading level0 col4" >4</th>        <th class="col_heading level0 col5" >5</th>        <th class="col_heading level0 col6" >6</th>        <th class="col_heading level0 col7" >7</th>        <th class="col_heading level0 col8" >8</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0f6e0_level0_row0" class="row_heading level0 row0" >media</th>
#                         <td id="T_0f6e0_row0_col0" class="data row0 col0" >870</td>
#                         <td id="T_0f6e0_row0_col1" class="data row0 col1" >870</td>
#                         <td id="T_0f6e0_row0_col2" class="data row0 col2" >863</td>
#                         <td id="T_0f6e0_row0_col3" class="data row0 col3" >511</td>
#                         <td id="T_0f6e0_row0_col4" class="data row0 col4" >870</td>
#                         <td id="T_0f6e0_row0_col5" class="data row0 col5" >842</td>
#                         <td id="T_0f6e0_row0_col6" class="data row0 col6" >770</td>
#                         <td id="T_0f6e0_row0_col7" class="data row0 col7" >900</td>
#                         <td id="T_0f6e0_row0_col8" class="data row0 col8" >870</td>
#             </tr>
#     </tbody></table>

# %%
# Construct vocabulary; using only train and valid dataset
tokenizer = get_tokenizer('mecab')
print('output :', tokenizer(SAMPLE_SENT))
# Out:
# output : ['ワンマンライブ', 'に', '行き', 'たい', '。']

# %% [markdown]
# ランダム

# %%
ld_df.loc[:, 'pred'] = [np.random.randint(9) for _ in range(len(ld_df))]

acc = sum(ld_df.media==ld_df.pred) / len(ld_df)
print('accuracy', acc)

cross = pd.crosstab(ld_df.media, ld_df.pred)
display(cross.style.background_gradient('Blues', axis=None))
# Out:
# accuracy 0.10969318490361119
# <style  type="text/css" >
# #T_a63b9_row0_col0,#T_a63b9_row1_col0,#T_a63b9_row2_col7,#T_a63b9_row4_col2,#T_a63b9_row5_col0,#T_a63b9_row8_col6{
#             background-color:  #2d7dbb;
#             color:  #000000;
#         }#T_a63b9_row0_col1,#T_a63b9_row0_col4,#T_a63b9_row1_col1,#T_a63b9_row4_col7,#T_a63b9_row5_col5{
#             background-color:  #2575b7;
#             color:  #000000;
#         }#T_a63b9_row0_col2,#T_a63b9_row1_col2{
#             background-color:  #135fa7;
#             color:  #f1f1f1;
#         }#T_a63b9_row0_col3{
#             background-color:  #5ba3d0;
#             color:  #000000;
#         }#T_a63b9_row0_col5,#T_a63b9_row1_col4,#T_a63b9_row6_col3,#T_a63b9_row7_col0{
#             background-color:  #3484bf;
#             color:  #000000;
#         }#T_a63b9_row0_col6,#T_a63b9_row5_col1{
#             background-color:  #4493c7;
#             color:  #000000;
#         }#T_a63b9_row0_col7{
#             background-color:  #083e81;
#             color:  #f1f1f1;
#         }#T_a63b9_row0_col8,#T_a63b9_row1_col8,#T_a63b9_row4_col0,#T_a63b9_row4_col4,#T_a63b9_row7_col5,#T_a63b9_row7_col6,#T_a63b9_row8_col1{
#             background-color:  #1c6ab0;
#             color:  #f1f1f1;
#         }#T_a63b9_row1_col3,#T_a63b9_row1_col6,#T_a63b9_row4_col3{
#             background-color:  #2171b5;
#             color:  #f1f1f1;
#         }#T_a63b9_row1_col5,#T_a63b9_row7_col7{
#             background-color:  #64a9d3;
#             color:  #000000;
#         }#T_a63b9_row1_col7,#T_a63b9_row2_col4,#T_a63b9_row4_col5{
#             background-color:  #115ca5;
#             color:  #f1f1f1;
#         }#T_a63b9_row2_col0,#T_a63b9_row8_col5{
#             background-color:  #084a91;
#             color:  #f1f1f1;
#         }#T_a63b9_row2_col1,#T_a63b9_row5_col4,#T_a63b9_row8_col7,#T_a63b9_row8_col8{
#             background-color:  #4d99ca;
#             color:  #000000;
#         }#T_a63b9_row2_col2,#T_a63b9_row2_col5,#T_a63b9_row5_col7,#T_a63b9_row7_col1,#T_a63b9_row8_col0{
#             background-color:  #3888c1;
#             color:  #000000;
#         }#T_a63b9_row2_col3,#T_a63b9_row2_col8,#T_a63b9_row5_col2{
#             background-color:  #3c8cc3;
#             color:  #000000;
#         }#T_a63b9_row2_col6,#T_a63b9_row4_col6{
#             background-color:  #1663aa;
#             color:  #f1f1f1;
#         }#T_a63b9_row3_col0,#T_a63b9_row3_col3,#T_a63b9_row3_col4{
#             background-color:  #c8dcf0;
#             color:  #000000;
#         }#T_a63b9_row3_col1{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_a63b9_row3_col2{
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }#T_a63b9_row3_col5,#T_a63b9_row3_col7{
#             background-color:  #d0e2f2;
#             color:  #000000;
#         }#T_a63b9_row3_col6{
#             background-color:  #cbdef1;
#             color:  #000000;
#         }#T_a63b9_row3_col8{
#             background-color:  #deebf7;
#             color:  #000000;
#         }#T_a63b9_row4_col1{
#             background-color:  #7ab6d9;
#             color:  #000000;
#         }#T_a63b9_row4_col8,#T_a63b9_row6_col6,#T_a63b9_row8_col2{
#             background-color:  #2a7ab9;
#             color:  #000000;
#         }#T_a63b9_row5_col3{
#             background-color:  #083370;
#             color:  #f1f1f1;
#         }#T_a63b9_row5_col6,#T_a63b9_row5_col8{
#             background-color:  #4896c8;
#             color:  #000000;
#         }#T_a63b9_row6_col0{
#             background-color:  #9cc9e1;
#             color:  #000000;
#         }#T_a63b9_row6_col1{
#             background-color:  #6dafd7;
#             color:  #000000;
#         }#T_a63b9_row6_col2,#T_a63b9_row6_col5{
#             background-color:  #5fa6d1;
#             color:  #000000;
#         }#T_a63b9_row6_col4{
#             background-color:  #3f8fc5;
#             color:  #000000;
#         }#T_a63b9_row6_col7{
#             background-color:  #74b3d8;
#             color:  #000000;
#         }#T_a63b9_row6_col8,#T_a63b9_row8_col3{
#             background-color:  #3181bd;
#             color:  #000000;
#         }#T_a63b9_row7_col2{
#             background-color:  #0e58a2;
#             color:  #f1f1f1;
#         }#T_a63b9_row7_col3{
#             background-color:  #084387;
#             color:  #f1f1f1;
#         }#T_a63b9_row7_col4{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_a63b9_row7_col8{
#             background-color:  #1967ad;
#             color:  #f1f1f1;
#         }#T_a63b9_row8_col4{
#             background-color:  #08468b;
#             color:  #f1f1f1;
#         }</style><table id="T_a63b9_" ><thead>    <tr>        <th class="index_name level0" >pred</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >2</th>        <th class="col_heading level0 col3" >3</th>        <th class="col_heading level0 col4" >4</th>        <th class="col_heading level0 col5" >5</th>        <th class="col_heading level0 col6" >6</th>        <th class="col_heading level0 col7" >7</th>        <th class="col_heading level0 col8" >8</th>    </tr>    <tr>        <th class="index_name level0" >media</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a63b9_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_a63b9_row0_col0" class="data row0 col0" >95</td>
#                         <td id="T_a63b9_row0_col1" class="data row0 col1" >97</td>
#                         <td id="T_a63b9_row0_col2" class="data row0 col2" >103</td>
#                         <td id="T_a63b9_row0_col3" class="data row0 col3" >84</td>
#                         <td id="T_a63b9_row0_col4" class="data row0 col4" >97</td>
#                         <td id="T_a63b9_row0_col5" class="data row0 col5" >93</td>
#                         <td id="T_a63b9_row0_col6" class="data row0 col6" >89</td>
#                         <td id="T_a63b9_row0_col7" class="data row0 col7" >112</td>
#                         <td id="T_a63b9_row0_col8" class="data row0 col8" >100</td>
#             </tr>
#             <tr>
#                         <th id="T_a63b9_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_a63b9_row1_col0" class="data row1 col0" >95</td>
#                         <td id="T_a63b9_row1_col1" class="data row1 col1" >97</td>
#                         <td id="T_a63b9_row1_col2" class="data row1 col2" >103</td>
#                         <td id="T_a63b9_row1_col3" class="data row1 col3" >98</td>
#                         <td id="T_a63b9_row1_col4" class="data row1 col4" >93</td>
#                         <td id="T_a63b9_row1_col5" class="data row1 col5" >82</td>
#                         <td id="T_a63b9_row1_col6" class="data row1 col6" >98</td>
#                         <td id="T_a63b9_row1_col7" class="data row1 col7" >104</td>
#                         <td id="T_a63b9_row1_col8" class="data row1 col8" >100</td>
#             </tr>
#             <tr>
#                         <th id="T_a63b9_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_a63b9_row2_col0" class="data row2 col0" >109</td>
#                         <td id="T_a63b9_row2_col1" class="data row2 col1" >87</td>
#                         <td id="T_a63b9_row2_col2" class="data row2 col2" >92</td>
#                         <td id="T_a63b9_row2_col3" class="data row2 col3" >91</td>
#                         <td id="T_a63b9_row2_col4" class="data row2 col4" >104</td>
#                         <td id="T_a63b9_row2_col5" class="data row2 col5" >92</td>
#                         <td id="T_a63b9_row2_col6" class="data row2 col6" >102</td>
#                         <td id="T_a63b9_row2_col7" class="data row2 col7" >95</td>
#                         <td id="T_a63b9_row2

# %% [markdown]
# 文長

# %%
ld_df.loc[:, 'tokens'] = ld_df['text'].apply(lambda x: [str(t) for t in tokenizer(x)])
summary = ld_df.groupby('media')['tokens'].agg([lambda x: np.mean(x.apply(len))]).rename(columns={'<lambda>': 'length'})
summary = summary.sort_values('length', ascending=False)
(summary + summary.shift(1))/2
# Out:
#            length
# media
# 1             NaN
# 3      828.257589
# 0      786.175405
# 4      731.385632
# 5      682.621251
# 8      657.987343
# 2      525.435499
# 6      385.335395
# 7      360.395202

# %%
def predict_by_len(tokens):
    df = ((summary + summary.shift(1))/2)[::-1]
    for ix, length in df.iterrows():
        if (len(tokens)<length.item()) or np.isnan(length.item()):
            label = ix
            break
        else:
            continue
    return label

predict_by_len(list(range(700)))

# %%
ld_df.loc[:, 'pred_by_len'] = ld_df['tokens'].apply(lambda x: predict_by_len(x))
ld_df.head()
# Out:
#    media                                               text  \
# 0      3  前回の「プロに聞く“合コンの極意”（前編）　合コンアナリスト水谷麻衣に聞く、合コンの勝ちパタ...
# 1      3  「3年で転職は早すぎる？」「将来が見えない」「仕事が面白くない」・・・若手社会人の悩みは尽き...
# 2      3  こんにちは、「ビズリーチ年収1000万円研究所」所長の佐藤和男です。この研究所では、年収10...
# 3      3  6月7日、表参道のカフェバー「MERCER CAFE TERRACE HOUSE」でHenn...
# 4      3  「3年で転職は早すぎる？」「将来が見えない」「仕事が面白くない」・・・若手社会人の悩みは尽き...
#
#                                               tokens  pred  pred_by_len
# 0  [前回, の, 「, プロ, に, 聞く, “, 合コン, の, 極意, ”, （, 前編,...     8            1
# 1  [「, 3年, で, 転職, は, 早, すぎる, ？, 」, 「, 将来, が, 見え, ...     0            6
# 2  [こんにちは, 、, 「, ビズリーチ, 年収, 1000万円, 研究所, 」, 所長, の...     8            8
# 3  [6月7日, 、, 表参道, の, カフェバー, 「, MERCER, CAFE, TERR...     5            2
# 4  [「, 3年, で, 転職, は, 早, すぎる, ？, 」, 「, 将来, が, 見え, ...     7            2

# %%
acc = sum(ld_df.media==ld_df.pred_by_len) / len(ld_df)
print('accuracy', acc)

cross = pd.crosstab(ld_df.media, ld_df.pred_by_len)
display(cross.style.background_gradient('Blues', axis=None))
# Out:
# accuracy 0.21069780070594624
# <style  type="text/css" >
# #T_3ce7b_row0_col0,#T_3ce7b_row0_col6,#T_3ce7b_row1_col2,#T_3ce7b_row5_col0,#T_3ce7b_row8_col4{
#             background-color:  #eaf3fb;
#             color:  #000000;
#         }#T_3ce7b_row0_col1{
#             background-color:  #63a8d3;
#             color:  #000000;
#         }#T_3ce7b_row0_col2{
#             background-color:  #aacfe5;
#             color:  #000000;
#         }#T_3ce7b_row0_col3,#T_3ce7b_row0_col4,#T_3ce7b_row4_col3{
#             background-color:  #ecf4fb;
#             color:  #000000;
#         }#T_3ce7b_row0_col5,#T_3ce7b_row5_col5{
#             background-color:  #eef5fc;
#             color:  #000000;
#         }#T_3ce7b_row0_col7{
#             background-color:  #d0e2f2;
#             color:  #000000;
#         }#T_3ce7b_row0_col8{
#             background-color:  #c1d9ed;
#             color:  #000000;
#         }#T_3ce7b_row1_col0,#T_3ce7b_row7_col6{
#             background-color:  #dfecf7;
#             color:  #000000;
#         }#T_3ce7b_row1_col1{
#             background-color:  #084184;
#             color:  #f1f1f1;
#         }#T_3ce7b_row1_col3{
#             background-color:  #e3eef9;
#             color:  #000000;
#         }#T_3ce7b_row1_col4,#T_3ce7b_row2_col8{
#             background-color:  #e0ecf8;
#             color:  #000000;
#         }#T_3ce7b_row1_col5,#T_3ce7b_row2_col0,#T_3ce7b_row3_col0,#T_3ce7b_row3_col4,#T_3ce7b_row4_col6,#T_3ce7b_row5_col6{
#             background-color:  #eff6fc;
#             color:  #000000;
#         }#T_3ce7b_row1_col6,#T_3ce7b_row6_col0,#T_3ce7b_row6_col3,#T_3ce7b_row6_col4,#T_3ce7b_row6_col5,#T_3ce7b_row7_col4{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_3ce7b_row1_col7{
#             background-color:  #f3f8fe;
#             color:  #000000;
#         }#T_3ce7b_row1_col8{
#             background-color:  #cde0f1;
#             color:  #000000;
#         }#T_3ce7b_row2_col1,#T_3ce7b_row4_col4,#T_3ce7b_row8_col3{
#             background-color:  #e8f1fa;
#             color:  #000000;
#         }#T_3ce7b_row2_col2{
#             background-color:  #a8cee4;
#             color:  #000000;
#         }#T_3ce7b_row2_col3,#T_3ce7b_row2_col5,#T_3ce7b_row6_col1,#T_3ce7b_row7_col0{
#             background-color:  #f5fafe;
#             color:  #000000;
#         }#T_3ce7b_row2_col4{
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }#T_3ce7b_row2_col6{
#             background-color:  #e1edf8;
#             color:  #000000;
#         }#T_3ce7b_row2_col7{
#             background-color:  #08509b;
#             color:  #f1f1f1;
#         }#T_3ce7b_row3_col1{
#             background-color:  #a0cbe2;
#             color:  #000000;
#         }#T_3ce7b_row3_col2{
#             background-color:  #d3e4f3;
#             color:  #000000;
#         }#T_3ce7b_row3_col3,#T_3ce7b_row3_col6,#T_3ce7b_row8_col5{
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }#T_3ce7b_row3_col5,#T_3ce7b_row7_col1,#T_3ce7b_row7_col5{
#             background-color:  #f5f9fe;
#             color:  #000000;
#         }#T_3ce7b_row3_col7,#T_3ce7b_row3_col8{
#             background-color:  #dfebf7;
#             color:  #000000;
#         }#T_3ce7b_row4_col0,#T_3ce7b_row6_col8{
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }#T_3ce7b_row4_col1{
#             background-color:  #72b2d8;
#             color:  #000000;
#         }#T_3ce7b_row4_col2{
#             background-color:  #91c3de;
#             color:  #000000;
#         }#T_3ce7b_row4_col5{
#             background-color:  #f0f6fd;
#             color:  #000000;
#         }#T_3ce7b_row4_col7{
#             background-color:  #d5e5f4;
#             color:  #000000;
#         }#T_3ce7b_row4_col8{
#             background-color:  #c2d9ee;
#             color:  #000000;
#         }#T_3ce7b_row5_col1,#T_3ce7b_row7_col2,#T_3ce7b_row8_col2{
#             background-color:  #a1cbe2;
#             color:  #000000;
#         }#T_3ce7b_row5_col2{
#             background-color:  #99c7e0;
#             color:  #000000;
#         }#T_3ce7b_row5_col3{
#             background-color:  #ebf3fb;
#             color:  #000000;
#         }#T_3ce7b_row5_col4{
#             background-color:  #e6f0f9;
#             color:  #000000;
#         }#T_3ce7b_row5_col7,#T_3ce7b_row8_col8{
#             background-color:  #cbdef1;
#             color:  #000000;
#         }#T_3ce7b_row5_col8{
#             background-color:  #bad6eb;
#             color:  #000000;
#         }#T_3ce7b_row6_col2{
#             background-color:  #8dc1dd;
#             color:  #000000;
#         }#T_3ce7b_row6_col6{
#             background-color:  #d6e5f4;
#             color:  #000000;
#         }#T_3ce7b_row6_col7{
#             background-color:  #2373b6;
#             color:  #f1f1f1;
#         }#T_3ce7b_row7_col3{
#             background-color:  #f6faff;
#             color:  #000000;
#         }#T_3ce7b_row7_col7{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_3ce7b_row7_col8{
#             background-color:  #dae8f6;
#             color:  #000000;
#         }#T_3ce7b_row8_col0{
#             background-color:  #e3eef8;
#             color:  #000000;
#         }#T_3ce7b_row8_col1{
#             background-color:  #a3cce3;
#             color:  #000000;
#         }#T_3ce7b_row8_col6{
#             background-color:  #edf4fc;
#             color:  #000000;
#         }#T_3ce7b_row8_col7{
#             background-color:  #a9cfe5;
#             color:  #000000;
#         }</style><table id="T_3ce7b_" ><thead>    <tr>        <th class="index_name level0" >pred_by_len</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >2</th>        <th class="col_heading level0 col3" >3</th>        <th class="col_heading level0 col4" >4</th>        <th class="col_heading level0 col5" >5</th>        <th class="col_heading level0 col6" >6</th>        <th class="col_heading level0 col7" >7</th>        <th class="col_heading level0 col8" >8</th>    </tr>    <tr>        <th class="index_name level0" >media</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3ce7b_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3ce7b_row0_col0" class="data row0 col0" >35</td>
#                         <td id="T_3ce7b_row0_col1" class="data row0 col1" >282</td>
#                         <td id="T_3ce7b_row0_col2" class="data row0 col2" >181</td>
#                         <td id="T_3ce7b_row0_col3" class="data row0 col3" >31</td>
#                         <td id="T_3ce7b_row0_col4" class="data row0 col4" >30</td>
#                         <td id="T_3ce7b_row0_col5" class="data row0 col5" >27</td>
#                         <td id="T_3ce7b_row0_col6" class="data row0 col6" >34</td>
#                         <td id="T_3ce7b_row0_col7" class="data row0 col7" >107</td>
#                         <td id="T_3ce7b_row0_col8" class="data row0 col8" >143</td>
#             </tr>
#             <tr>
#                         <th id="T_3ce7b_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_3ce7b_row1_col0" class="data row1 col0" >65</td>
#                         <td id="T_3ce7b_row1_col1" class="data row1 col1" >503</td>
#                         <td id="T_3ce7b_row1_col2" class="data row1 col2" >35</td>
#                         <td id="T_3ce7b_row1_col3" class="data row1 col3" >54</td>
#                         <td id="T_3ce7b_row1_col4" class="data row1 col4" >62</td>
#                         <td id="T_3ce7b_row1_col5" class="data row1 col5" >23</td>
#                         <td id="T_3ce7b_row1_col6" class="data row1 col6" >2</td>
#                         <td id="T_3ce7b_row1_col7" class="data row1 col7" >12</td>
#                         <td id="T_3ce7b_row1_col

# %% [markdown]
# 語の出現頻度

# %%
texts = [tokenizer(str(t)) for i, (l, t) in ld_df.iterrows()]
freq = Counter(itertools.chain.from_iterable(texts)).most_common()
freq[:10]
# Out:
# [('、', 203844),
#  ('の', 196481),
#  ('。', 134637),
#  ('に', 126605),
#  ('を', 123117),
#  ('が', 112796),
#  ('は', 109134),
#  ('て', 99219),
#  ('で', 81866),
#  ('た', 81702)]
