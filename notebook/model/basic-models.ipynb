# %%
import spacy
import gensim
import os
import re
import pandas as pd
from gensim.models import KeyedVectors
from joblib import Parallel, delayed
import itertools
import numpy as np
import pickle

# %% [markdown]
# data

# %%
# %%time
dataset = pd.read_parquet('data/word_embeddings.parquet.gz')
dataset.head()
# Out:
# CPU times: user 37.1 s, sys: 14.6 s, total: 51.7 s
# Wall time: 59.6 s
#           media                                               url  \
# 0  sports-watch  http://news.livedoor.com/article/detail/5985384/
# 1  sports-watch  http://news.livedoor.com/article/detail/6819620/
# 2  sports-watch  http://news.livedoor.com/article/detail/5571206/
# 3  sports-watch  http://news.livedoor.com/article/detail/4970500/
# 4  sports-watch  http://news.livedoor.com/article/detail/6158040/
#
#                   timestamp                                   title  \
# 0  2011-11-02T09:00:00+0900               石川遼、“異例の交際発表”めぐる水面下の攻防とは？
# 1  2012-08-03T10:00:00+0900             柔道界の現状に、古賀氏「日本の場合は先生の圧力が強い」
# 2  2011-05-20T02:00:00+0900  【Sports Watch】女性店員の契約選手侮辱ツイートでアディダスが謝罪
# 3  2010-08-27T07:25:00+0900  【Sports Watch】スエマエの五輪後、前田は「人間不信になった感じ」
# 4  2011-12-30T09:00:00+0900              天皇杯で敗れたチームのファン（？）、チケットを燃やす
#
#                                                 text  \
# 0  先月24日深夜、プロゴルファー・石川遼が、マネジメント会社「ケーアイ企画」を通し、一般女性と...
# 1  ロンドン五輪における柔道男子は、ここまで金メダルを獲得できずにいる。2日も男子100kg級に...
# 2  ヴァンフォーレ甲府のFWで、アディダス契約選手の一人＝ハーフナー・マイクが、18日に入籍を発...
# 3  2008年、北京五輪の舞台で世界ランキング一位のペアから金星を挙げ、一躍その名を知らしめた女...
# 4  29日に行なわれた第91回天皇杯全日本サッカー選手権大会は、J2のFC東京と京都サンガが決勝...
#
#                                               tokens  \
# 0  [先月, 24, 日, 深夜, 、, プロゴルファー, ・, 石川, 遼, が, 、, マネ...
# 1  [ロンドン, 五輪, に, おけ, る, 柔道, 男子, は, 、, ここ, まで, 金, ...
# 2  [ヴァン, フォーレ, 甲府, の, FW, で, 、, アディダス, 契約, 選手, の,...
# 3  [2008, 年, 、, 北京, 五輪, の, 舞台, で, 世界, ランキング, 一, 位...
# 4  [29, 日, に, 行なわ, れ, た, 第, 91, 回, 天皇, 杯, 全, 日本, ...
#
#                                           embeddings
# 0  [[-0.071045354, -0.25821245, 0.14480348, -0.22...
# 1  [[-0.09269952, 0.5426098, 0.12492261, -0.18234...
# 2  [[-0.12361497, 0.050540913, -0.46253157, -0.16...
# 3  [[0.19916902, -0.079966575, 0.2989788, -0.0169...
# 4  [[0.19836882, -0.106275775, 0.3315136, -0.2118...

# %% [markdown]
# ## feature-engineering

# %%
dataset.loc[:, 'emb_mean'] = dataset['embeddings'].apply(np.mean)
dataset.head()
# Out:
#           media                                               url  \
# 0  sports-watch  http://news.livedoor.com/article/detail/5985384/
# 1  sports-watch  http://news.livedoor.com/article/detail/6819620/
# 2  sports-watch  http://news.livedoor.com/article/detail/5571206/
# 3  sports-watch  http://news.livedoor.com/article/detail/4970500/
# 4  sports-watch  http://news.livedoor.com/article/detail/6158040/
#
#                   timestamp                                   title  \
# 0  2011-11-02T09:00:00+0900               石川遼、“異例の交際発表”めぐる水面下の攻防とは？
# 1  2012-08-03T10:00:00+0900             柔道界の現状に、古賀氏「日本の場合は先生の圧力が強い」
# 2  2011-05-20T02:00:00+0900  【Sports Watch】女性店員の契約選手侮辱ツイートでアディダスが謝罪
# 3  2010-08-27T07:25:00+0900  【Sports Watch】スエマエの五輪後、前田は「人間不信になった感じ」
# 4  2011-12-30T09:00:00+0900              天皇杯で敗れたチームのファン（？）、チケットを燃やす
#
#                                                 text  \
# 0  先月24日深夜、プロゴルファー・石川遼が、マネジメント会社「ケーアイ企画」を通し、一般女性と...
# 1  ロンドン五輪における柔道男子は、ここまで金メダルを獲得できずにいる。2日も男子100kg級に...
# 2  ヴァンフォーレ甲府のFWで、アディダス契約選手の一人＝ハーフナー・マイクが、18日に入籍を発...
# 3  2008年、北京五輪の舞台で世界ランキング一位のペアから金星を挙げ、一躍その名を知らしめた女...
# 4  29日に行なわれた第91回天皇杯全日本サッカー選手権大会は、J2のFC東京と京都サンガが決勝...
#
#                                               tokens  \
# 0  [先月, 24, 日, 深夜, 、, プロゴルファー, ・, 石川, 遼, が, 、, マネ...
# 1  [ロンドン, 五輪, に, おけ, る, 柔道, 男子, は, 、, ここ, まで, 金, ...
# 2  [ヴァン, フォーレ, 甲府, の, FW, で, 、, アディダス, 契約, 選手, の,...
# 3  [2008, 年, 、, 北京, 五輪, の, 舞台, で, 世界, ランキング, 一, 位...
# 4  [29, 日, に, 行なわ, れ, た, 第, 91, 回, 天皇, 杯, 全, 日本, ...
#
#                                           embeddings  \
# 0  [[-0.071045354, -0.25821245, 0.14480348, -0.22...
# 1  [[-0.09269952, 0.5426098, 0.12492261, -0.18234...
# 2  [[-0.12361497, 0.050540913, -0.46253157, -0.16...
# 3  [[0.19916902, -0.079966575, 0.2989788, -0.0169...
# 4  [[0.19836882, -0.106275775, 0.3315136, -0.2118...
#
#                                             emb_mean
# 0  [0.074116744, -0.06302879, -0.018419443, -0.07...
# 1  [0.100644544, -0.023868158, 0.005920538, -0.07...
# 2  [0.1261884, -0.029592466, -0.0027288257, -0.07...
# 3  [0.10523655, -0.024903512, -0.0035270725, -0.0...
# 4  [0.10481595, -0.0038150423, 0.0053625847, -0.0...

# %%
# text と tokens は一致（tokenize による欠損は無し）
re.sub(' ', '', dataset['text'][0]) == dataset['tokens'].apply(lambda x: ''.join(x))[0]
# Out:
# True

# %%
# token -> embedding で欠損あり；LSTM など単語シーケンスを受け付けるモデルでの推論においては同品詞単語の平均で補完すべき？
print(len(dataset['tokens'][0]))
print(len(dataset['embeddings'][0]))
# Out:
# 540
# 490

# %% [markdown]
# ## modeling

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC, LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score, classification_report

# %%
X = np.array(dataset['emb_mean'].to_list())
y = dataset['media']
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=dataset['media'], random_state=5108)

# %%
# check if stratified
pd.concat([y_train.value_counts()/y_train.value_counts().sum(), y_test.value_counts()/y_test.value_counts().sum()], axis=1)
# Out:
#                    media     media
# sports-watch    0.122194  0.122150
# movie-enter     0.118030  0.118350
# smax            0.118030  0.118350
# dokujo-tsushin  0.118030  0.117807
# it-life-hack    0.118030  0.118350
# kaden-channel   0.117306  0.117264
# peachy          0.114410  0.114007
# topic-news      0.104634  0.104235
# livedoor-homme  0.069334  0.069490

# %%
def train_test(model):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    y_pred_train = model.predict(X_train)
    return y_pred, y_pred_train

models = [LinearSVC(), SVC(), RandomForestClassifier(), DecisionTreeClassifier()]
results = []
for model in models:
    results.append(train_test(model))
for y_pred, y_pred_train in results:
    print(accuracy_score(y_test, y_pred))
    print(accuracy_score(y_train, y_pred_train), '\n')
# Out:
# 0.8713355048859935
# 0.8973569876900797
#
# 0.8403908794788274
# 0.8595220854453295
#
# 0.8338762214983714
# 1.0
#
# 0.6346362649294245
# 1.0

# %%
for y_pred, y_pred_train in results:
    display(pd.crosstab(y_test, y_pred).style.background_gradient('Blues'))
# Out:
# <style  type="text/css" >
# #T_9a1ce_row0_col0,#T_9a1ce_row1_col1,#T_9a1ce_row2_col2,#T_9a1ce_row3_col3,#T_9a1ce_row4_col4,#T_9a1ce_row5_col5,#T_9a1ce_row6_col6,#T_9a1ce_row7_col7,#T_9a1ce_row8_col8{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_9a1ce_row0_col1,#T_9a1ce_row0_col7,#T_9a1ce_row1_col5,#T_9a1ce_row2_col6,#T_9a1ce_row3_col6,#T_9a1ce_row4_col7,#T_9a1ce_row4_col8,#T_9a1ce_row5_col1,#T_9a1ce_row5_col6,#T_9a1ce_row6_col4,#T_9a1ce_row8_col0,#T_9a1ce_row8_col4,#T_9a1ce_row8_col5{
#             background-color:  #f6faff;
#             color:  #000000;
#         }#T_9a1ce_row0_col2,#T_9a1ce_row1_col7,#T_9a1ce_row3_col8,#T_9a1ce_row5_col7,#T_9a1ce_row5_col8,#T_9a1ce_row7_col0{
#             background-color:  #f5fafe;
#             color:  #000000;
#         }#T_9a1ce_row0_col3,#T_9a1ce_row0_col8,#T_9a1ce_row2_col8,#T_9a1ce_row3_col1{
#             background-color:  #f3f8fe;
#             color:  #000000;
#         }#T_9a1ce_row0_col4,#T_9a1ce_row8_col7{
#             background-color:  #f0f6fd;
#             color:  #000000;
#         }#T_9a1ce_row0_col5{
#             background-color:  #e0ecf8;
#             color:  #000000;
#         }#T_9a1ce_row0_col6,#T_9a1ce_row1_col3,#T_9a1ce_row2_col7,#T_9a1ce_row4_col1,#T_9a1ce_row4_col2,#T_9a1ce_row4_col3,#T_9a1ce_row4_col6,#T_9a1ce_row6_col0,#T_9a1ce_row6_col2,#T_9a1ce_row6_col3,#T_9a1ce_row6_col5,#T_9a1ce_row6_col7,#T_9a1ce_row6_col8,#T_9a1ce_row7_col1,#T_9a1ce_row7_col2,#T_9a1ce_row7_col4,#T_9a1ce_row7_col5,#T_9a1ce_row7_col6,#T_9a1ce_row8_col2,#T_9a1ce_row8_col6{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_9a1ce_row1_col0,#T_9a1ce_row1_col4,#T_9a1ce_row3_col2,#T_9a1ce_row5_col2,#T_9a1ce_row8_col1{
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }#T_9a1ce_row1_col2,#T_9a1ce_row1_col6,#T_9a1ce_row2_col5,#T_9a1ce_row4_col5,#T_9a1ce_row7_col3,#T_9a1ce_row8_col3{
#             background-color:  #f1f7fd;
#             color:  #000000;
#         }#T_9a1ce_row1_col8,#T_9a1ce_row7_col8{
#             background-color:  #eff6fc;
#             color:  #000000;
#         }#T_9a1ce_row2_col0,#T_9a1ce_row3_col0,#T_9a1ce_row3_col5{
#             background-color:  #eef5fc;
#             color:  #000000;
#         }#T_9a1ce_row2_col1{
#             background-color:  #ecf4fb;
#             color:  #000000;
#         }#T_9a1ce_row2_col3,#T_9a1ce_row5_col3{
#             background-color:  #edf4fc;
#             color:  #000000;
#         }#T_9a1ce_row2_col4,#T_9a1ce_row3_col4{
#             background-color:  #f5f9fe;
#             color:  #000000;
#         }#T_9a1ce_row3_col7,#T_9a1ce_row6_col1{
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }#T_9a1ce_row4_col0{
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }#T_9a1ce_row5_col0{
#             background-color:  #d9e8f5;
#             color:  #000000;
#         }#T_9a1ce_row5_col4{
#             background-color:  #eaf3fb;
#             color:  #000000;
#         }</style><table id="T_9a1ce_" ><thead>    <tr>        <th class="index_name level0" >col_0</th>        <th class="col_heading level0 col0" >dokujo-tsushin</th>        <th class="col_heading level0 col1" >it-life-hack</th>        <th class="col_heading level0 col2" >kaden-channel</th>        <th class="col_heading level0 col3" >livedoor-homme</th>        <th class="col_heading level0 col4" >movie-enter</th>        <th class="col_heading level0 col5" >peachy</th>        <th class="col_heading level0 col6" >smax</th>        <th class="col_heading level0 col7" >sports-watch</th>        <th class="col_heading level0 col8" >topic-news</th>    </tr>    <tr>        <th class="index_name level0" >media</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9a1ce_level0_row0" class="row_heading level0 row0" >dokujo-tsushin</th>
#                         <td id="T_9a1ce_row0_col0" class="data row0 col0" >181</td>
#                         <td id="T_9a1ce_row0_col1" class="data row0 col1" >1</td>
#                         <td id="T_9a1ce_row0_col2" class="data row0 col2" >2</td>
#                         <td id="T_9a1ce_row0_col3" class="data row0 col3" >2</td>
#                         <td id="T_9a1ce_row0_col4" class="data row0 col4" >8</td>
#                         <td id="T_9a1ce_row0_col5" class="data row0 col5" >18</td>
#                         <td id="T_9a1ce_row0_col6" class="data row0 col6" >0</td>
#                         <td id="T_9a1ce_row0_col7" class="data row0 col7" >1</td>
#                         <td id="T_9a1ce_row0_col8" class="data row0 col8" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_9a1ce_level0_row1" class="row_heading level0 row1" >it-life-hack</th>
#                         <td id="T_9a1ce_row1_col0" class="data row1 col0" >3</td>
#                         <td id="T_9a1ce_row1_col1" class="data row1 col1" >188</td>
#                         <td id="T_9a1ce_row1_col2" class="data row1 col2" >6</td>
#                         <td id="T_9a1ce_row1_col3" class="data row1 col3" >0</td>
#                         <td id="T_9a1ce_row1_col4" class="data row1 col4" >4</td>
#                         <td id="T_9a1ce_row1_col5" class="data row1 col5" >1</td>
#                         <td id="T_9a1ce_row1_col6" class="data row1 col6" >7</td>
#                         <td id="T_9a1ce_row1_col7" class="data row1 col7" >2</td>
#                         <td id="T_9a1ce_row1_col8" class="data row1 col8" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_9a1ce_level0_row2" class="row_heading level0 row2" >kaden-channel</th>
#                         <td id="T_9a1ce_row2_col0" class="data row2 col0" >8</td>
#                         <td id="T_9a1ce_row2_col1" class="data row2 col1" >11</td>
#                         <td id="T_9a1ce_row2_col2" class="data row2 col2" >179</td>
#                         <td id="T_9a1ce_row2_col3" class="data row2 col3" >5</td>
#                         <td id="T_9a1ce_row2_col4" class="data row2 col4" >3</td>
#                         <td id="T_9a1ce_row2_col5" class="data row2 col5" >5</td>
#                         <td id="T_9a1ce_row2_col6" class="data row2 col6" >1</td>
#                         <td id="T_9a1ce_row2_col7" class="data row2 col7" >0</td>
#                         <td id="T_9a1ce_row2_col8" class="data row2 col8" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_9a1ce_level0_row3" class="row_heading level0 row3" >livedoor-homme</th>
#                         <td id="T_9a1ce_row3_col0" class="data row3 col0" >8</td>
#                         <td id="T_9a1ce_row3_col1" class="data row3 col1" >4</td>
#                         <td id="T_9a1ce_row3_col2" class="data row3 col2" >3</td>
#                         <td id="T_9a1ce_row3_col3" class="data row3 col3" >95</td>
#                         <td id="T_9a1ce_row3_col4" class="data row3 col4" >3</td>
#                         <td id="T_9a1ce_row3_col5" class="data row3 col5" >7</td>
#                         <td id="T_9a1ce_row3_col6" class="data row3 col6" >1</td>
#                         <td id="T_9a1ce_row3_col7" class="data row3 col7" >5</td>
#                         <td id="T_9a1ce_row3_col8" class="data row3 col8" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_9a1ce_level0_row4" class="row_heading level0 row4" >movie-enter</th>
#                         <td id="T_9a1ce_row4_col0" class="data row4 col0" >5</td>
#                         <td id="T_9a1ce_row4_col1" class="data row4 col1" >0</td>
#                         <td id="T_9a1ce_row4_col2" class="data row4 col2" >0</td>
#                         <td id="T_9a1ce_row4_col3" class="data row4 col3" >0</td>
# <style  type="text/css" >
# #T_1a027_row0_col0,#T_1a027_row1_col1,#T_1a027_row2_col2,#T_1a027_row3_col3,#T_1a027_row4_col4,#T_1a027_row5_col5,#T_1a027_row6_col6,#T_1a027_row7_col7,#T_1a027_row8_col8{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_1a027_row0_col1,#T_1a027_row0_col7,#T_1a027_row1_col5,#T_1a027_row3_col8,#T_1a027_row4_col8,#T_1a027_row5_col6,#T_1a027_row5_col7,#T_1a027_row5_col8,#T_1a027_row8_col4{
#             background-color:  #f6faff;
#             color:  #000000;
#         }#T_1a027_row0_col2,#T_1a027_row0_col6,#T_1a027_row1_col3,#T_1a027_row2_col7,#T_1a027_row3_col6,#T_1a027_row4_col1,#T_1a027_row4_col2,#T_1a027_row4_col6,#T_1a027_row4_col7,#T_1a027_row6_col0,#T_1a027_row6_col2,#T_1a027_row6_col3,#T_1a027_row6_col4,#T_1a027_row6_col7,#T_1a027_row6_col8,#T_1a027_row7_col0,#T_1a027_row7_col1,#T_1a027_row7_col2,#T_1a027_row7_col4,#T_1a027_row7_col5,#T_1a027_row7_col6,#T_1a027_row8_col2,#T_1a027_row8_col5,#T_1a027_row8_col6{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_1a027_row0_col3{
#             background-color:  #eaf3fb;
#             color:  #000000;
#         }#T_1a027_row0_col4,#T_1a027_row2_col8{
#             background-color:  #edf4fc;
#             color:  #000000;
#         }#T_1a027_row0_col5{
#             background-color:  #ddeaf7;
#             color:  #000000;
#         }#T_1a027_row0_col8,#T_1a027_row3_col2,#T_1a027_row3_col4,#T_1a027_row5_col1,#T_1a027_row5_col2{
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }#T_1a027_row1_col0,#T_1a027_row4_col5,#T_1a027_row8_col1{
#             background-color:  #f3f8fe;
#             color:  #000000;
#         }#T_1a027_row1_col2,#T_1a027_row2_col0,#T_1a027_row2_col5,#T_1a027_row3_col1,#T_1a027_row4_col0{
#             background-color:  #eef5fc;
#             color:  #000000;
#         }#T_1a027_row1_col4{
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }#T_1a027_row1_col6{
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }#T_1a027_row1_col7,#T_1a027_row2_col6,#T_1a027_row8_col0{
#             background-color:  #f5fafe;
#             color:  #000000;
#         }#T_1a027_row1_col8{
#             background-color:  #f1f7fd;
#             color:  #000000;
#         }#T_1a027_row2_col1{
#             background-color:  #e5eff9;
#             color:  #000000;
#         }#T_1a027_row2_col3{
#             background-color:  #e8f1fa;
#             color:  #000000;
#         }#T_1a027_row2_col4,#T_1a027_row3_col7,#T_1a027_row4_col3,#T_1a027_row6_col5,#T_1a027_row8_col3{
#             background-color:  #f5f9fe;
#             color:  #000000;
#         }#T_1a027_row3_col0,#T_1a027_row6_col1{
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }#T_1a027_row3_col5{
#             background-color:  #e3eef9;
#             color:  #000000;
#         }#T_1a027_row5_col0{
#             background-color:  #d6e6f4;
#             color:  #000000;
#         }#T_1a027_row5_col3{
#             background-color:  #e6f0f9;
#             color:  #000000;
#         }#T_1a027_row5_col4,#T_1a027_row7_col8{
#             background-color:  #eaf2fb;
#             color:  #000000;
#         }#T_1a027_row7_col3{
#             background-color:  #f0f6fd;
#             color:  #000000;
#         }#T_1a027_row8_col7{
#             background-color:  #eff6fc;
#             color:  #000000;
#         }</style><table id="T_1a027_" ><thead>    <tr>        <th class="index_name level0" >col_0</th>        <th class="col_heading level0 col0" >dokujo-tsushin</th>        <th class="col_heading level0 col1" >it-life-hack</th>        <th class="col_heading level0 col2" >kaden-channel</th>        <th class="col_heading level0 col3" >livedoor-homme</th>        <th class="col_heading level0 col4" >movie-enter</th>        <th class="col_heading level0 col5" >peachy</th>        <th class="col_heading level0 col6" >smax</th>        <th class="col_heading level0 col7" >sports-watch</th>        <th class="col_heading level0 col8" >topic-news</th>    </tr>    <tr>        <th class="index_name level0" >media</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1a027_level0_row0" class="row_heading level0 row0" >dokujo-tsushin</th>
#                         <td id="T_1a027_row0_col0" class="data row0 col0" >176</td>
#                         <td id="T_1a027_row0_col1" class="data row0 col1" >1</td>
#                         <td id="T_1a027_row0_col2" class="data row0 col2" >0</td>
#                         <td id="T_1a027_row0_col3" class="data row0 col3" >5</td>
#                         <td id="T_1a027_row0_col4" class="data row0 col4" >11</td>
#                         <td id="T_1a027_row0_col5" class="data row0 col5" >20</td>
#                         <td id="T_1a027_row0_col6" class="data row0 col6" >0</td>
#                         <td id="T_1a027_row0_col7" class="data row0 col7" >1</td>
#                         <td id="T_1a027_row0_col8" class="data row0 col8" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_1a027_level0_row1" class="row_heading level0 row1" >it-life-hack</th>
#                         <td id="T_1a027_row1_col0" class="data row1 col0" >4</td>
#                         <td id="T_1a027_row1_col1" class="data row1 col1" >186</td>
#                         <td id="T_1a027_row1_col2" class="data row1 col2" >8</td>
#                         <td id="T_1a027_row1_col3" class="data row1 col3" >0</td>
#                         <td id="T_1a027_row1_col4" class="data row1 col4" >6</td>
#                         <td id="T_1a027_row1_col5" class="data row1 col5" >1</td>
#                         <td id="T_1a027_row1_col6" class="data row1 col6" >5</td>
#                         <td id="T_1a027_row1_col7" class="data row1 col7" >2</td>
#                         <td id="T_1a027_row1_col8" class="data row1 col8" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_1a027_level0_row2" class="row_heading level0 row2" >kaden-channel</th>
#                         <td id="T_1a027_row2_col0" class="data row2 col0" >8</td>
#                         <td id="T_1a027_row2_col1" class="data row2 col1" >17</td>
#                         <td id="T_1a027_row2_col2" class="data row2 col2" >164</td>
#                         <td id="T_1a027_row2_col3" class="data row2 col3" >6</td>
#                         <td id="T_1a027_row2_col4" class="data row2 col4" >3</td>
#                         <td id="T_1a027_row2_col5" class="data row2 col5" >7</td>
#                         <td id="T_1a027_row2_col6" class="data row2 col6" >2</td>
#                         <td id="T_1a027_row2_col7" class="data row2 col7" >0</td>
#                         <td id="T_1a027_row2_col8" class="data row2 col8" >9</td>
#             </tr>
#             <tr>
#                         <th id="T_1a027_level0_row3" class="row_heading level0 row3" >livedoor-homme</th>
#                         <td id="T_1a027_row3_col0" class="data row3 col0" >14</td>
#                         <td id="T_1a027_row3_col1" class="data row3 col1" >8</td>
#                         <td id="T_1a027_row3_col2" class="data row3 col2" >3</td>
#                         <td id="T_1a027_row3_col3" class="data row3 col3" >80</td>
#                         <td id="T_1a027_row3_col4" class="data row3 col4" >4</td>
#                         <td id="T_1a027_row3_col5" class="data row3 col5" >15</td>
#                         <td id="T_1a027_row3_col6" class="data row3 col6" >0</td>
#                         <td id="T_1a027_row3_col7" class="data row3 col7" >3</td>
#                         <td id="T_1a027_row3_col8" class="data row3 col8" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_1a027_level0_row4"
# <style  type="text/css" >
# #T_93a0e_row0_col0,#T_93a0e_row1_col1,#T_93a0e_row2_col2,#T_93a0e_row3_col3,#T_93a0e_row4_col4,#T_93a0e_row5_col5,#T_93a0e_row6_col6,#T_93a0e_row7_col7,#T_93a0e_row8_col8{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_93a0e_row0_col1,#T_93a0e_row2_col7,#T_93a0e_row3_col6,#T_93a0e_row4_col1,#T_93a0e_row4_col3,#T_93a0e_row4_col6,#T_93a0e_row6_col0,#T_93a0e_row6_col3,#T_93a0e_row6_col4,#T_93a0e_row6_col7,#T_93a0e_row6_col8,#T_93a0e_row7_col0,#T_93a0e_row7_col1,#T_93a0e_row7_col2,#T_93a0e_row7_col4,#T_93a0e_row7_col5,#T_93a0e_row7_col6,#T_93a0e_row8_col5,#T_93a0e_row8_col6{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_93a0e_row0_col2,#T_93a0e_row1_col4,#T_93a0e_row3_col2,#T_93a0e_row3_col4,#T_93a0e_row3_col8,#T_93a0e_row4_col8,#T_93a0e_row5_col6,#T_93a0e_row6_col2{
#             background-color:  #f5f9fe;
#             color:  #000000;
#         }#T_93a0e_row0_col3,#T_93a0e_row2_col3,#T_93a0e_row3_col5{
#             background-color:  #e5eff9;
#             color:  #000000;
#         }#T_93a0e_row0_col4{
#             background-color:  #ecf4fb;
#             color:  #000000;
#         }#T_93a0e_row0_col5{
#             background-color:  #e7f0fa;
#             color:  #000000;
#         }#T_93a0e_row0_col6,#T_93a0e_row0_col7,#T_93a0e_row1_col7,#T_93a0e_row3_col7,#T_93a0e_row4_col2,#T_93a0e_row4_col7,#T_93a0e_row8_col0{
#             background-color:  #f6faff;
#             color:  #000000;
#         }#T_93a0e_row0_col8,#T_93a0e_row4_col5,#T_93a0e_row5_col1{
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }#T_93a0e_row1_col0,#T_93a0e_row2_col4,#T_93a0e_row4_col0,#T_93a0e_row5_col2,#T_93a0e_row5_col8,#T_93a0e_row6_col5,#T_93a0e_row8_col1{
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }#T_93a0e_row1_col2{
#             background-color:  #e6f0f9;
#             color:  #000000;
#         }#T_93a0e_row1_col3,#T_93a0e_row5_col7,#T_93a0e_row8_col3,#T_93a0e_row8_col4{
#             background-color:  #f5fafe;
#             color:  #000000;
#         }#T_93a0e_row1_col5,#T_93a0e_row1_col8,#T_93a0e_row5_col4,#T_93a0e_row8_col7{
#             background-color:  #eef5fc;
#             color:  #000000;
#         }#T_93a0e_row1_col6,#T_93a0e_row2_col8,#T_93a0e_row3_col1,#T_93a0e_row6_col1{
#             background-color:  #ebf3fb;
#             color:  #000000;
#         }#T_93a0e_row2_col0{
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }#T_93a0e_row2_col1{
#             background-color:  #e3eef9;
#             color:  #000000;
#         }#T_93a0e_row2_col5{
#             background-color:  #eaf3fb;
#             color:  #000000;
#         }#T_93a0e_row2_col6,#T_93a0e_row7_col3{
#             background-color:  #f3f8fe;
#             color:  #000000;
#         }#T_93a0e_row3_col0{
#             background-color:  #edf4fc;
#             color:  #000000;
#         }#T_93a0e_row5_col0{
#             background-color:  #ddeaf7;
#             color:  #000000;
#         }#T_93a0e_row5_col3{
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }#T_93a0e_row7_col8{
#             background-color:  #e9f2fa;
#             color:  #000000;
#         }#T_93a0e_row8_col2{
#             background-color:  #f1f7fd;
#             color:  #000000;
#         }</style><table id="T_93a0e_" ><thead>    <tr>        <th class="index_name level0" >col_0</th>        <th class="col_heading level0 col0" >dokujo-tsushin</th>        <th class="col_heading level0 col1" >it-life-hack</th>        <th class="col_heading level0 col2" >kaden-channel</th>        <th class="col_heading level0 col3" >livedoor-homme</th>        <th class="col_heading level0 col4" >movie-enter</th>        <th class="col_heading level0 col5" >peachy</th>        <th class="col_heading level0 col6" >smax</th>        <th class="col_heading level0 col7" >sports-watch</th>        <th class="col_heading level0 col8" >topic-news</th>    </tr>    <tr>        <th class="index_name level0" >media</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_93a0e_level0_row0" class="row_heading level0 row0" >dokujo-tsushin</th>
#                         <td id="T_93a0e_row0_col0" class="data row0 col0" >176</td>
#                         <td id="T_93a0e_row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_93a0e_row0_col2" class="data row0 col2" >2</td>
#                         <td id="T_93a0e_row0_col3" class="data row0 col3" >8</td>
#                         <td id="T_93a0e_row0_col4" class="data row0 col4" >12</td>
#                         <td id="T_93a0e_row0_col5" class="data row0 col5" >13</td>
#                         <td id="T_93a0e_row0_col6" class="data row0 col6" >1</td>
#                         <td id="T_93a0e_row0_col7" class="data row0 col7" >1</td>
#                         <td id="T_93a0e_row0_col8" class="data row0 col8" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_93a0e_level0_row1" class="row_heading level0 row1" >it-life-hack</th>
#                         <td id="T_93a0e_row1_col0" class="data row1 col0" >3</td>
#                         <td id="T_93a0e_row1_col1" class="data row1 col1" >169</td>
#                         <td id="T_93a0e_row1_col2" class="data row1 col2" >14</td>
#                         <td id="T_93a0e_row1_col3" class="data row1 col3" >1</td>
#                         <td id="T_93a0e_row1_col4" class="data row1 col4" >3</td>
#                         <td id="T_93a0e_row1_col5" class="data row1 col5" >7</td>
#                         <td id="T_93a0e_row1_col6" class="data row1 col6" >12</td>
#                         <td id="T_93a0e_row1_col7" class="data row1 col7" >1</td>
#                         <td id="T_93a0e_row1_col8" class="data row1 col8" >8</td>
#             </tr>
#             <tr>
#                         <th id="T_93a0e_level0_row2" class="row_heading level0 row2" >kaden-channel</th>
#                         <td id="T_93a0e_row2_col0" class="data row2 col0" >5</td>
#                         <td id="T_93a0e_row2_col1" class="data row2 col1" >17</td>
#                         <td id="T_93a0e_row2_col2" class="data row2 col2" >158</td>
#                         <td id="T_93a0e_row2_col3" class="data row2 col3" >8</td>
#                         <td id="T_93a0e_row2_col4" class="data row2 col4" >4</td>
#                         <td id="T_93a0e_row2_col5" class="data row2 col5" >10</td>
#                         <td id="T_93a0e_row2_col6" class="data row2 col6" >4</td>
#                         <td id="T_93a0e_row2_col7" class="data row2 col7" >0</td>
#                         <td id="T_93a0e_row2_col8" class="data row2 col8" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_93a0e_level0_row3" class="row_heading level0 row3" >livedoor-homme</th>
#                         <td id="T_93a0e_row3_col0" class="data row3 col0" >9</td>
#                         <td id="T_93a0e_row3_col1" class="data row3 col1" >10</td>
#                         <td id="T_93a0e_row3_col2" class="data row3 col2" >2</td>
#                         <td id="T_93a0e_row3_col3" class="data row3 col3" >87</td>
#                         <td id="T_93a0e_row3_col4" class="data row3 col4" >3</td>
#                         <td id="T_93a0e_row3_col5" class="data row3 col5" >14</td>
#                         <td id="T_93a0e_row3_col6" class="data row3 col6" >0</td>
#                         <td id="T_93a0e_row3_col7" class="data row3 col7" >1</td>
#                         <td id="T_93a0e_row3_col8" class="data row3 col8" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_93a0e_level0_row4" class="row_heading level0 row4" >movie-enter</th>
#                         <
# <style  type="text/css" >
# #T_84f8d_row0_col0,#T_84f8d_row1_col1,#T_84f8d_row2_col2,#T_84f8d_row3_col3,#T_84f8d_row4_col4,#T_84f8d_row5_col5,#T_84f8d_row6_col6,#T_84f8d_row7_col7,#T_84f8d_row8_col8{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_84f8d_row0_col1,#T_84f8d_row0_col2,#T_84f8d_row0_col6,#T_84f8d_row1_col4,#T_84f8d_row1_col7,#T_84f8d_row4_col2,#T_84f8d_row6_col0,#T_84f8d_row6_col3,#T_84f8d_row6_col5,#T_84f8d_row6_col8,#T_84f8d_row7_col1,#T_84f8d_row7_col2{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_84f8d_row0_col3,#T_84f8d_row0_col5{
#             background-color:  #caddf0;
#             color:  #000000;
#         }#T_84f8d_row0_col4,#T_84f8d_row8_col7{
#             background-color:  #e3eef9;
#             color:  #000000;
#         }#T_84f8d_row0_col7,#T_84f8d_row8_col0{
#             background-color:  #f0f6fd;
#             color:  #000000;
#         }#T_84f8d_row0_col8{
#             background-color:  #edf4fc;
#             color:  #000000;
#         }#T_84f8d_row1_col0,#T_84f8d_row3_col4,#T_84f8d_row4_col1,#T_84f8d_row5_col1,#T_84f8d_row8_col3{
#             background-color:  #eef5fc;
#             color:  #000000;
#         }#T_84f8d_row1_col2{
#             background-color:  #c7dcef;
#             color:  #000000;
#         }#T_84f8d_row1_col3{
#             background-color:  #d3e4f3;
#             color:  #000000;
#         }#T_84f8d_row1_col5,#T_84f8d_row3_col6{
#             background-color:  #f5fafe;
#             color:  #000000;
#         }#T_84f8d_row1_col6{
#             background-color:  #d6e6f4;
#             color:  #000000;
#         }#T_84f8d_row1_col8,#T_84f8d_row2_col3,#T_84f8d_row4_col8{
#             background-color:  #eaf2fb;
#             color:  #000000;
#         }#T_84f8d_row2_col0,#T_84f8d_row5_col8{
#             background-color:  #ebf3fb;
#             color:  #000000;
#         }#T_84f8d_row2_col1{
#             background-color:  #d0e1f2;
#             color:  #000000;
#         }#T_84f8d_row2_col4,#T_84f8d_row2_col7,#T_84f8d_row8_col4{
#             background-color:  #f5f9fe;
#             color:  #000000;
#         }#T_84f8d_row2_col5,#T_84f8d_row5_col4{
#             background-color:  #e8f1fa;
#             color:  #000000;
#         }#T_84f8d_row2_col6,#T_84f8d_row6_col2{
#             background-color:  #eaf3fb;
#             color:  #000000;
#         }#T_84f8d_row2_col8{
#             background-color:  #dfebf7;
#             color:  #000000;
#         }#T_84f8d_row3_col0{
#             background-color:  #e1edf8;
#             color:  #000000;
#         }#T_84f8d_row3_col1,#T_84f8d_row3_col2{
#             background-color:  #f1f7fd;
#             color:  #000000;
#         }#T_84f8d_row3_col5{
#             background-color:  #deebf7;
#             color:  #000000;
#         }#T_84f8d_row3_col7,#T_84f8d_row4_col6,#T_84f8d_row7_col5,#T_84f8d_row8_col5,#T_84f8d_row8_col6{
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }#T_84f8d_row3_col8,#T_84f8d_row5_col6,#T_84f8d_row5_col7{
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }#T_84f8d_row4_col0{
#             background-color:  #e9f2fa;
#             color:  #000000;
#         }#T_84f8d_row4_col3{
#             background-color:  #e7f0fa;
#             color:  #000000;
#         }#T_84f8d_row4_col5{
#             background-color:  #dae8f6;
#             color:  #000000;
#         }#T_84f8d_row4_col7,#T_84f8d_row5_col2,#T_84f8d_row8_col2{
#             background-color:  #eff6fc;
#             color:  #000000;
#         }#T_84f8d_row5_col0{
#             background-color:  #bed8ec;
#             color:  #000000;
#         }#T_84f8d_row5_col3{
#             background-color:  #c6dbef;
#             color:  #000000;
#         }#T_84f8d_row6_col1{
#             background-color:  #d8e7f5;
#             color:  #000000;
#         }#T_84f8d_row6_col4,#T_84f8d_row6_col7,#T_84f8d_row7_col6{
#             background-color:  #f6faff;
#             color:  #000000;
#         }#T_84f8d_row7_col0,#T_84f8d_row8_col1{
#             background-color:  #e4eff9;
#             color:  #000000;
#         }#T_84f8d_row7_col3{
#             background-color:  #e0ecf8;
#             color:  #000000;
#         }#T_84f8d_row7_col4{
#             background-color:  #f3f8fe;
#             color:  #000000;
#         }#T_84f8d_row7_col8{
#             background-color:  #d9e7f5;
#             color:  #000000;
#         }</style><table id="T_84f8d_" ><thead>    <tr>        <th class="index_name level0" >col_0</th>        <th class="col_heading level0 col0" >dokujo-tsushin</th>        <th class="col_heading level0 col1" >it-life-hack</th>        <th class="col_heading level0 col2" >kaden-channel</th>        <th class="col_heading level0 col3" >livedoor-homme</th>        <th class="col_heading level0 col4" >movie-enter</th>        <th class="col_heading level0 col5" >peachy</th>        <th class="col_heading level0 col6" >smax</th>        <th class="col_heading level0 col7" >sports-watch</th>        <th class="col_heading level0 col8" >topic-news</th>    </tr>    <tr>        <th class="index_name level0" >media</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_84f8d_level0_row0" class="row_heading level0 row0" >dokujo-tsushin</th>
#                         <td id="T_84f8d_row0_col0" class="data row0 col0" >135</td>
#                         <td id="T_84f8d_row0_col1" class="data row0 col1" >2</td>
#                         <td id="T_84f8d_row0_col2" class="data row0 col2" >3</td>
#                         <td id="T_84f8d_row0_col3" class="data row0 col3" >18</td>
#                         <td id="T_84f8d_row0_col4" class="data row0 col4" >17</td>
#                         <td id="T_84f8d_row0_col5" class="data row0 col5" >27</td>
#                         <td id="T_84f8d_row0_col6" class="data row0 col6" >0</td>
#                         <td id="T_84f8d_row0_col7" class="data row0 col7" >6</td>
#                         <td id="T_84f8d_row0_col8" class="data row0 col8" >9</td>
#             </tr>
#             <tr>
#                         <th id="T_84f8d_level0_row1" class="row_heading level0 row1" >it-life-hack</th>
#                         <td id="T_84f8d_row1_col0" class="data row1 col0" >6</td>
#                         <td id="T_84f8d_row1_col1" class="data row1 col1" >117</td>
#                         <td id="T_84f8d_row1_col2" class="data row1 col2" >34</td>
#                         <td id="T_84f8d_row1_col3" class="data row1 col3" >15</td>
#                         <td id="T_84f8d_row1_col4" class="data row1 col4" >2</td>
#                         <td id="T_84f8d_row1_col5" class="data row1 col5" >4</td>
#                         <td id="T_84f8d_row1_col6" class="data row1 col6" >29</td>
#                         <td id="T_84f8d_row1_col7" class="data row1 col7" >0</td>
#                         <td id="T_84f8d_row1_col8" class="data row1 col8" >11</td>
#             </tr>
#             <tr>
#                         <th id="T_84f8d_level0_row2" class="row_heading level0 row2" >kaden-channel</th>
#                         <td id="T_84f8d_row2_col0" class="data row2 col0" >8</td>
#                         <td id="T_84f8d_row2_col1" class="data row2 col1" >25</td>
#                         <td id="T_84f8d_row2_col2" class="data row2 col2" >129</td>
#                         <td id="T_84f8d_row2_col3" class="data row2 col3" >8</td>
#                         <td id="T_84f8d_row2_col4" class="data row2 col4" >4</td>
#                         <td id="T_84f8d_row2_col5" class="data row2 col5" >11</td>
#                         <td id="T_84f8d_row2_col6" class="data row2 col6" >11</td>
#                         <td id="T_84f8d_row2_col7" class="data row2 col7" >2</td>
#                         <td id="T_84f8d_row2_col8" class="data row2 col8" >18</td>
#             </
